# %% [markdown]
# ### Rectangle Overlap

# %% [markdown]
# A rectangle is represented as a list [x1, y1, x2, y2], where (x1, y1) are the coordinates of its bottom-left corner, and (x2, y2) are the coordinates of its top-right corner.
#
# Two rectangles overlap if the area of their intersection is positive.  To be clear, two rectangles that only touch at the corner or edges do not overlap.
#
# Given two (axis-aligned) rectangles, return whether they overlap.
# ##### Example 1:
# Input: rec1 = [0,0,2,2], rec2 = [1,1,3,3]
#
# Output: true
# ##### Example 2:
# Input: rec1 = [0,0,1,1], rec2 = [1,0,2,1]
#
# Output: false

# %%
def isRectangleOverlap(self, rec1: list, rec2: list) -> bool:
    if rec2[0] >= rec1[0] and rec2[0] < rec1[2]:
        if rec2[1] <= rec1[1]:
            return True if rec2[3] > rec1[1] else False
            
        elif rec2[1] > rec1[1]:
            return True if rec2[1] <= rec1[3] else False
            
        
    if rec2[0] <= rec1[0] and rec1[0] < rec2[2]:
        if rec2[1] <= rec1[1]:
            return True if rec2[3] > rec1[1] else False
            
        elif rec2[1] > rec1[1]:
            return True if rec2[1] <= rec1[3] else False

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1564596171289.jpg",width=400,height=400)
