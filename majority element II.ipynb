# %% [markdown]
# ### Majority Element II

# %% [markdown]
# Given an integer array of size n, find all elements that appear more than ⌊ n/3 ⌋ times.
#
# Note: The algorithm should run in linear time and in O(1) space.
# ##### Example 1:
# Input: [3, 2, 3]
#
# Output: [3]
# ##### Example 2:
# Input: [1, 1, 1, 3, 3, 2, 2, 2]
#
# Output: [1, 2]

# %% [markdown]
# ### Brief analysis
# hard to achieve O(1) space though succeed

# %%
def majorityElement(nums: list) -> list:
    new = []
    for i in set(nums):
        if nums.count(i) > len(nums) // 3:
            new.append(i)
    return new

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1559510411936.jpg",width=400,height=400)
