# %% [markdown]
# ### Single Number

# %% [markdown]
# Given a non-empty array of integers, every element appears twice except for one. Find that single one.
# #### Note:
# Your algorithm should have a linear runtime complexity. Could you implement it without using extra memory?
# ##### Example 1:
# Input: [2, 2, 1]
#
# Output: 1
# ##### Example 2:
# Input: [4, 1, 2, 1, 2]
#
# Output: 4

# %% [markdown]
# #### Brief analysis
# Find the single value without counting, we make use of the function 'set' to filter repeat and achieve goals by subtraction.

# %%
def singleNumber(nums) -> int:
        
        return 2 * sum(list(set(nums))) - sum(nums)

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1558713097312.jpg",width=400,height=400)
