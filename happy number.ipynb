# %% [markdown]
# ### Happy Number

# %% [markdown]
# Write an algorithm to determine if a number is "happy".
#
# A happy number is a number defined by the following process: Starting with any positive integer, replace the number by the sum of the squares of its
#
# digits, and repeat the process until the number equals 1 (where it will stay), or it loops endlessly in a cycle which does not include 1. Those numbers
# for which this process ends in 1 are happy numbers.
# ##### Example:
# Input: 19
#
# Output: true
#
# Explanation:
#
# 12 + 92 = 82
#
# 82 + 22 = 68
#
# 62 + 82 = 100
#
# 12 + 02 + 02 = 1

# %%
def isHappy(self, n: int) -> bool:
    nums = set()
    nums.add(n)
        
    while n > 1:
        l1 = len(nums)
        new = 0
        for i in str(n):
            new += int(i) ** 2
        n = new
        nums.add(n)
        l2 = len(nums)
            
        if l1 == l2:
            return False
            
    return True

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1561662660467.jpg",width=400,height=400)
