# %% [markdown]
# ### Search a 2D Matrix

# %% [markdown]
# Write an efficient algorithm that searches for a value in an m x n matrix. This matrix has the following properties:
#
# Integers in each row are sorted from left to right.
#
# The first integer of each row is greater than the last integer of the previous row.
# ##### Example 1:
# Input:
#
# matrix = [
#
# [1,   3,  5,  7],
#
# [10, 11, 16, 20],
#
# [23, 30, 34, 50]
#
# ]
#
# target = 3
#
# Output: true
# ##### Example 2:
# Input:
#
# matrix = [
#
# [1,   3,  5,  7],
#
# [10, 11, 16, 20],
#
# [23, 30, 34, 50]
#
# ]
#
# target = 13
#
# Output: false

# %%
def searchMatrix(self, matrix: list, target: int) -> bool:
    if not matrix:
        return False
        
    if any(len(matrix[i]) == 0 for i in range(len(matrix))):
        return False
        
    if target < matrix[0][0] or target > matrix[-1][-1]:
        return False
        
    for i in range(1, len(matrix)):
        if matrix[i][0] > target:
            return any(j == target for j in matrix[i - 1])
        
    return any(k == target for k in matrix[len(matrix) - 1])

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1566666986373.jpg",width=400,height=400)
