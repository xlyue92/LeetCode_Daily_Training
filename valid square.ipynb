# %% [markdown]
# ### Valid Square

# %% [markdown]
# Given the coordinates of four points in 2D space, return whether the four points could construct a square.
#
# The coordinate (x,y) of a point is represented by an integer array with two integers.
# ##### Example:
# Input: p1 = [0, 0], p2 = [1, 1], p3 = [1, 0], p4 = [0, 1]
#
# Output: True

# %% [markdown]
# ### Brief analysis
# based on definition of a square

# %%
def validSquare(self, p1: list, p2: list, p3: list, p4: list) -> bool:
    def dist(x, y):
        return (x[0] - y[0])**2 + (x[1] - y[1])**2
    
    new = [dist(p1, p2), dist(p1, p3), dist(p1, p4), dist(p2, p3), dist(p2, p4), dist(p3, p4)]
    new = sorted(new)
        
    return new[0] > 0 and new[0] == new[1] == new[2] == new[3] and new[-1] == new[-2]

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1560121552063.jpg",width=400,height=400)
