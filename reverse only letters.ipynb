# %% [markdown]
# ### Reverse Only Letters

# %% [markdown]
# Given a string S, return the "reversed" string where all characters that are not a letter stay in the same place, and all letters reverse their positions.
# ##### Example 1:
# Input: "ab-cd"
#
# Output: "dc-ba"
# ##### Example 2:
# Input: "a-bC-dEf-ghIj"
#
# Output: "j-Ih-gfE-dCba"
# ##### Example 3:
# Input: "Test1ng-Leet=code-Q!"
#
# Output: "Qedo1ct-eeLg=ntse-T!"

# %% [markdown]
# ### Brief analysis
# use pop() function to 'append' every last element in the new list and combine with each non-letter element.

# %%
def reverseOnlyLetters(S: str) -> str:
        new = [i for i in S if i.isalpha()]
        return ''.join(new.pop() if i.isalpha() else i for i in S)

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1559067974961.jpg",width=400,height=400)
