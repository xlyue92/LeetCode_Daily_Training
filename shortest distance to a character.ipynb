# %% [markdown]
# ### Shortest Distance to a Character

# %% [markdown]
# Given a string S and a character C, return an array of integers representing the shortest distance from the character C in the string.
# ##### Example 1:
# Input: S = "loveleetcode", C = 'e'
#
# Output: [3, 2, 1, 0, 1, 0, 0, 1, 2, 2, 1, 0]
#
# Note:
#
# S string length is in [1, 10000].
#
# C is a single character, and guaranteed to be in string S.
#
# All letters in S and C are lowercase.

# %%
def shortestToChar(self, S: str, C: str) -> list:
    if len(S) == 1:
        return [0]
        
    s = [i for i in range(len(S)) if S[i] == C]
    new = []
        
    if len(s) == 1:
        for j in range(len(S)):
            new += [abs(j - s[0])]
        return new
        
    else:
        for j in range(len(S)):
            if j <= s[0]:
                new += [s[0] - j]
            for k in range(len(s) - 1):
                if j > s[k] and j <= s[k + 1]:
                    new += [min(j - s[k], s[k + 1] - j)]
            if j > s[-1]:
                new +=[j - s[-1]]
        return new

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1561754985054.jpg",width=400,height=400)
