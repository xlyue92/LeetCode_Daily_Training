# %% [markdown]
# ### Power of Four

# %% [markdown]
# Given an integer (signed 32 bits), write a function to check whether it is a power of 4.
# ##### Example 1:
# Input: 16
#
# Output: true
# ##### Example 2:
# Input: 5
#
# Output: false

# %%
def isPowerOfFour(self, num: int) -> bool:
    if num == 1:
        return True
        
    if 1 < num < 4:
        return False
        
    temp = bin(num)[2:]
    n = len(temp)
    if n % 2 == 0:
        return False
        
    if temp[0] == '1' and all(i == '0' for i in temp[1:]):
        return True
        
    return False

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1567613293635.jpg",width=400,height=400)
