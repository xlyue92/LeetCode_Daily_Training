# %% [markdown]
# ### First Missing Positive

# %% [markdown]
# Given an unsorted integer array, find the smallest missing positive integer.
# ##### Example 1:
# Input: [1, 2, 0]
#
# Output: 3
# ##### Example 2:
# Input: [3, 4, -1, 1]
#
# Output: 2
# ##### Example 3:
# Input: [7, 8, 9, 11, 12]
#
# Output: 1
# #### Note:
# Your algorithm should run in O(n) time and uses constant extra space.

# %% [markdown]
# ### Brief analysis
# use loop to print this number.

# %%
def firstMissingPositive(nums) -> int:
    out = 1
    for i in sorted(nums):
        if i == out:
            out += 1
    return out

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1558908417069.jpg",width=400,height=400)
