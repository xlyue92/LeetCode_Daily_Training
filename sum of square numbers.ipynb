# %% [markdown]
# ### Sum of Square Numbers

# %% [markdown]
# Given a non-negative integer c, your task is to decide whether there're two integers a and b such that a$^2$ + b$^2$ = c.
# ##### Example 1:
# Input: 5
#
# Output: True
#
# Explanation: 1 * 1 + 2 * 2 = 5
# ##### Example 2:
# Input: 3
#
# Output: False

# %% [markdown]
# ### Brief analysis
# verify if x or y is int.

# %%
def judgeSquareSum(c: int) -> bool:
    n = 0
    for i in range(int(c**0.5) + 1):
        if (c - i**2)**0.5 % 1 == 0:
            n = 1
            break
    return n > 0

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1559165505650.jpg",width=400,height=400)
