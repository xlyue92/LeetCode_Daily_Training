# %% [markdown]
# ### Single Number III

# %% [markdown]
# Given an array of numbers nums, in which exactly two elements appear only once and all the other elements appear exactly twice. Find the two elements that appear only once.
# ##### Example:
# Input:  [1, 2, 1, 3, 2, 5]
#
# Output: [3,5]

# %% [markdown]
# ### Brief analysis
# for loop, do not use count function, will lead to TLE

# %%
def singleNumber(self, nums: list) -> list:
    new = set()
    for i in nums:
        if i not in new:
            new.add(i)
        else:
            new.remove(i)
    return list(new)

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1560143593692.jpg",width=400,height=400)
