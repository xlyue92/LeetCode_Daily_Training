# %% [markdown]
# ### Climbing Stairs

# %% [markdown]
# You are climbing a stair case. It takes n steps to reach to the top.
#
# Each time you can either climb 1 or 2 steps. In how many distinct ways can you climb to the top?
#
# Note: Given n will be a positive integer.
# ##### Example 1:
# Input: 2
#
# Output: 2
#
# Explanation: There are two ways to climb to the top.
# 1. 1 step + 1 step
#
# 2. 2 steps
#
# ##### Example 2:
# Input: 3
#
# Output: 3
#
# Explanation: There are three ways to climb to the top.
#
# 1. 1 step + 1 step + 1 step
#
# 2. 1 step + 2 steps
#
# 3. 2 steps + 1 step

# %% [markdown]
# ### Brief analysis
# primitive solution & fibo method

# %%
def climbStairs(n: int) -> int:
    def factorial(m):
        if m == 0:
            return 1
        else: 
            return m * factorial(m - 1)
    
    c = 1
    s = n // 2
    for i in range(1, s + 1):
        if n - 2 * i < n and n - 2 * i > 0:
            c += factorial(n - i) / (factorial(i) * factorial(n - 2 * i))
    return int(c + 1) if n % 2 == 0 else int(c)

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1559763928488.jpg",width=400,height=400)

# %%
def climbStairs(n: int) -> int:
    a, b = 1, 1
    for i in range(n):
        a, b = b, a + b
    return a

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1559764017634.jpg",width=400,height=400)
