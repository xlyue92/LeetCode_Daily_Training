# %% [markdown]
# ### Valid Boomerang

# %% [markdown]
# A boomerang is a set of 3 points that are all distinct and not in a straight line.
#
# Given a list of three points in the plane, return whether these points are a boomerang.
# ##### Example 1:
# Input: [[1, 1],[2, 3],[3, 2]]
#
# Output: true
# ##### Example 2:
# Input: [[1, 1],[2, 2],[3, 3]]
#
# Output: false

# %% [markdown]
# ### Brief analysis
# def of slope

# %%
def isBoomerang(points: list) -> bool:
    return (points[2][1] - points[1][1]) * (points[1][0] - points[0][0]) != (points[1][1] - points[0][1]) * (points[2][0] - points[1][0])

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1559235445174.jpg",width=400,height=400)
