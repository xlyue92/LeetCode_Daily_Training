# %% [markdown]
# ###  Largest Time for Given Digits

# %% [markdown]
# Given an array of 4 digits, return the largest 24 hour time that can be made.
#
# The smallest 24 hour time is 00:00, and the largest is 23:59.  Starting from 00:00, a time is larger if more time has elapsed since midnight.
#
# Return the answer as a string of length 5.  If no valid time can be made, return an empty string.
# ##### Example 1:
# Input: [1,2,3,4]
#
# Output: "23:41"
# ##### Example 2:
# Input: [5,5,5,5]
#
# Output: ""

# %%
def largestTimeFromDigits(self, A: list) -> str:
    a = ''.join(map(str, A))
    new = list(set(map(''.join, itertools.permutations(a))))
    res = '0000'
        
    if all(i > '2359' for i in new):
        return ''
        
    for i in range(len(new)):
        if new[i] <= '2359' and new[i][2] <= '5':
            res = max(res, new[i])
                
        if res == '0000':
            return '00:00' if all(i == 0 for i in A) else ''
        else:
            return res[:2] + ':' + res[2:]

# %%
from IPython.display import Image
Image(filename="/Users/xlyue/Documents/leetcode practice/1563293711897.jpg",width=400,height=400)
